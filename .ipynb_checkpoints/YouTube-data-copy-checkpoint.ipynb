# %% [markdown]
# source: https://www.kaggle.com/hoonkeng/deep-analysis-on-youtube-trending-videos-eda/notebook

# %%
# Import the necessary packages and modules
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /Users/rosemaryperez/Desktop/YouTube_RoseMaryPerez

# %%
# !ls ../YouTubeData
# Out:
# dataframe.csv                dataframe_all_timestamps.csv

# %%
# Pandas df dateframe

filepath = "YouTubeData"
filename1 = os.path.join('..',filepath,'dataframe.csv')
filename2 = os.path.join('..',filepath,'dataframe_all_timestamps.csv')

#print(filename1, filename2)
df = pd.read_csv(filename1)
df_all_timestamps = pd.read_csv(filename2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171149 entries, 0 to 171148
# Data columns (total 19 columns):
# video_id                  171149 non-null object
# trending_date             171149 non-null object
# title                     171149 non-null object
# channel_title             171149 non-null object
# category_id               171149 non-null int64
# category                  171149 non-null object
# publish_date              171149 non-null object
# publish_time              171149 non-null object
# tags                      171149 non-null object
# views                     171149 non-null int64
# likes                     171149 non-null int64
# dislikes                  171149 non-null int64
# comment_count             171149 non-null int64
# thumbnail_link            171149 non-null object
# comments_disabled         171149 non-null bool
# ratings_disabled          171149 non-null bool
# video_error_or_removed    171149 non-null bool
# description               171149 non-null object
# country                   171149 non-null object
# dtypes: bool(3), int64(5), object(11)
# memory usage: 21.4+ MB

# %%
df_all_timestamps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356350 entries, 0 to 356349
# Data columns (total 19 columns):
# video_id                  356350 non-null object
# trending_date             356350 non-null object
# title                     356350 non-null object
# channel_title             356350 non-null object
# category_id               356350 non-null int64
# category                  356350 non-null object
# publish_date              356350 non-null object
# publish_time              356350 non-null object
# tags                      356350 non-null object
# views                     356350 non-null int64
# likes                     356350 non-null int64
# dislikes                  356350 non-null int64
# comment_count             356350 non-null int64
# thumbnail_link            356350 non-null object
# comments_disabled         356350 non-null bool
# ratings_disabled          356350 non-null bool
# video_error_or_removed    356350 non-null bool
# description               356350 non-null object
# country                   356350 non-null object
# dtypes: bool(3), int64(5), object(11)
# memory usage: 44.5+ MB

# %%
df.category_id
# Out:
# 0          1
# 1         20
# 2         25
# 3          1
# 4         23
#           ..
# 171144    17
# 171145    26
# 171146    24
# 171147    22
# 171148    20
# Name: category_id, Length: 171149, dtype: int64

# %%
df.category
# Out:
# 0         Film & Animation
# 1                   Gaming
# 2          News & Politics
# 3         Film & Animation
# 4                   Comedy
#                 ...
# 171144              Sports
# 171145       Howto & Style
# 171146       Entertainment
# 171147      People & Blogs
# 171148              Gaming
# Name: category, Length: 171149, dtype: object

# %%
df [['category', 'category_id']]
# Out:
#                 category  category_id
# 0       Film & Animation            1
# 1                 Gaming           20
# 2        News & Politics           25
# 3       Film & Animation            1
# 4                 Comedy           23
# ...                  ...          ...
# 171144            Sports           17
# 171145     Howto & Style           26
# 171146     Entertainment           24
# 171147    People & Blogs           22
# 171148            Gaming           20
#
# [171149 rows x 2 columns]

# %%
#1
# title: Sets the title of the chart, which is passed as an argument.
# ylabel: Sets the label of the Y axis. xlabel can be used to set the label of the X axis.
# yticks: Sets which ticks to show on the Y axis. xticks is the corresponding option for showing ticks on the X axis.
# legend: Displays the legend on the plot. The loc argument of the .legend() method sets the position of the legend
# on the graph. The best option for the loc arguments lets Matplotlib decide the least intrusive position of the
# legend on the figure.

plt.plot([0,1,2,3,4], label ='y = x')
plt.title('Y = X One Straight Line')
plt.ylabel('Y Axis')
plt.xlabel('X Axis')
plt.yticks([1,2,3,4])
plt.xticks([1,2,3,4])
plt.legend(loc = 'best')
plt.show()

# %%
# 2
plt.plot([0,1,2,3,4], label='y = x')
plt.plot([0,2,4,6,8], label='y = 2x')

plt.title('Two Straight Lines')
plt.ylabel('Y Axis')
plt.xlabel('X Axis')
plt.legend(loc = 'best')
plt.show()

# %%
#3
#To create a scatter plot of points on the XY plane, use the .scatter() method
plt.scatter([1,2,3,4], [5,1,4,2])
plt.show()

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'category', 'publish_date', 'publish_time', 'tags', 'views', 'likes',
#        'dislikes', 'comment_count', 'thumbnail_link', 'comments_disabled',
#        'ratings_disabled', 'video_error_or_removed', 'description', 'country'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of            video_id trending_date  \
# 0       cJon8yBKv3g    2017-11-14
# 1       g12KeCPRB4Q    2017-11-14
# 2       irIZRH3JlIw    2017-11-14
# 3       SnHtzkQZggA    2017-11-14
# 4       u6EoWM2KMPE    2017-11-14
# ...             ...           ...
# 171144  qLM1NA272v0    2018-06-14
# 171145  xpP9TR0M5e8    2018-06-14
# 171146  WxJ4SfmUGgY    2018-06-14
# 171147  znUg17W526o    2018-06-14
# 171148  ooyjaVdt-jA    2018-06-14
#
#                                                     title  \
# 0          Kingsman : Le Cercle d'or (Mickael J Critique)
# 1                    Vide grenier LIVE - 12 Novembre 2017
# 2       لقجع يثور في وجه الإتحاد الإيفواري بسبب الجماه...
# 3        عروس اسطنبول | اعلان الحلقة 25 | - مترجم للعربية
# 4       Portokalli, 12 Nentor 2017 - Policat e postbll...
# ...                                                   ...
# 171144  حصري/ شاهد ماذا فعل مشجعون مغاربة بتركي آل شيخ...
# 171145  Nach 37 Sekunden passiert etwas im Ofen, das j...
# 171146  НЕРЯХА ДЖО! БУРГЕР для детей и взрослых (здоро...
# 171147                      Die Wahrheit über die WM 2018
# 171148  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  category_id          category publish_date  \
# 0                 MJ - FERMEZ LA            1  Film & Animation   2017-11-12
# 1                       Kirby-54           20            Gaming   2017-11-12
# 2                    أخبار اليوم           25   News & Politics   2017-11-12
# 3       تركييتنا - bizim Türkiye            1  Film & Animation   2017-11-13
# 4            Top Channel Albania           23            Comedy   2017-11-13
# ...                          ...          ...               ...          ...
# 171144                  Elbotola           17            Sports   2018-06-13
# 171145           Leckerschmecker           26     Howto & Style   2018-06-13
# 171146                  oblomoff           24     Entertainment   2018-06-13
# 171147               MrWissen2go           22    People & Blogs   2018-06-13
# 171148              Call of Duty           20            Gaming   2018-05-17
#
#        publish_time                                               tags  \
# 0          17:58:57  VoxMakers"|"FERMEZ LA"|"Alert Spoiler"|"Matthe...
# 1          13:46:18  Vide grenier"|"vide grenier live"|"brocante"|"...
# 2          19:08:08  قناة أخبار اليوم"|"يومية المغرب"|"دولية"|"قضية...
# 3          19:58:33  مسلسل عروس اسطنبول"|"عروس اسطنبول"|"عروس اسطنب...
# 4          13:33:26  Portokalli"|"Comedy Show"|"Top Channel Albania...
# ...             ...                                                ...
# 171144     20:59:22  Elbotola.com|"elbotolatv"|"elbotolaMedia"|"الب...
# 171145     16:30:03  Leckerschmecker|"Rezepte"|"kochen"|"backen"|"k...
# 171146     11:04:35  рецепт|"дачный рецепт"|"рецепт на углях"|"реце...
# 171147     12:30:02  wissen2go|"mrwissen2go"|"fußballweltmeistersch...
# 171148     17:09:38      call of duty|"cod"|"activision"|"Black Ops 4"
#
#            views   likes  dislikes  comment_count  \
# 0          19487    1596        23            215
# 1          20744    1032       558            243
# 2         207452    1415       148             90
# 3          15899     142        10              7
# 4         100607    1159        48             35
# ...          ...     ...       ...            ...
# 171144    179322    1890       346           2229
# 171145     29630    1029        36             55
# 171146    587480   35688      1207           2380
# 171147    164294    9065       453           1632
# 171148  10306119  357079    212976         144795
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/cJon8yBKv3g/default.jpg              False
# 1       https://i.ytimg.com/vi/g12KeCPRB4Q/default.jpg              False
# 2       https://i.ytimg.com/vi/irIZRH3JlIw/default.jpg              False
# 3       https://i.ytimg.com/vi/SnHtzkQZggA/default.jpg              False
# 4       https://i.ytimg.com/vi/u6EoWM2KMPE/default.jpg              False
# ...                                                ...                ...
# 171144  https://i.ytimg.com/vi/qLM1NA272v0/default.jpg              False
# 171145  https://i.ytimg.com/vi/xpP9TR0M5e8/default.jpg              False
# 171146  https://i.ytimg.com/vi/WxJ4SfmUGgY/default.jpg              False
# 171147  https://i.ytimg.com/vi/znUg17W526o/default.jpg              False
# 171148  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 171144             False                   False
# 171145             False                   False
# 171146             False                   False
# 171147             False                   False
# 171148             False                   False
#
#                                               description country
# 0       Avec un peu de retard, voici l'avis de Mickael...      FR
# 1       C'est reparti pour un nouveau compte rendu vid...      FR
# 2       لقجع يثور في وجه الإتحاد الإيفواري بسبب الجماه...      FR
# 3       عروس اسطنبول | اعلان الحلقة 25 | - مترجم للعرب...      FR
# 4              http://top-channel.tv/programe/portokalli/      FR
# ...                                                   ...     ...
# 171144  اضغط و اشترك في قناتنا : http://bit.ly/2oEM69K...      DE
# 171145  Auf Pinterest merken: http://bit.ly/2xZZooyDie...      DE
# 171146  Купи свой Биван со скидкой 20% по промокоду СЛ...      DE
# 171147  Keine Frage - die Fußball-Weltermeisterschaft ...      DE
# 171148  Call of Duty: Black Ops 4 Multiplayer raises t...      US
#
# [171149 rows x 19 columns]>

# %%
fig = plt.figure(figsize=(8,8)) # define plot area and size it
ax = fig.gca() # define axis 


plt.plot([0,1,2,3,4], label='y = x')
plt.plot([0,2,4,6,8], label='y = 2x')

plt.title('Two Straight Lines')
plt.ylabel('Y Axis')
plt.xlabel('X Axis')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ### df.groupby(col1).agg(np.mean)
# ### Find the average across all columns for every unique col1 group

# %%
df.groupby('category')['views'].agg('count').plot(kind='barh',title='Group-By Country');

# %%
df.groupby('likes')['views'].agg('count').plot(kind='barh',title='Group-By Likes');
# Out:
# Error in callback <function flush_figures at 0x1a1cb9e598> (for post_execute):
# ------------------------------------------------------------
# KeyboardInterrupt          Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/rosemaryperez/miniconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2375                 try:
#    2376                     bbox = ax.get_tightbbox(renderer,
# -> 2377                             bbox_extra_artists=bbox_extra_artists)
#    2378                 except TypeError:
#    2379                     bbox = ax.get_tightbbox(renderer)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4357                 bb.append(bb_xaxis)
#    4358
# -> 4359             bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4360             if bb_yaxis:
#    4361                 bb.append(bb_yaxis)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2306         # get bounding boxes for this axis and any siblings
#    2307         # that have been set by `fig.align_ylabels()`
# -> 2308         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2309
#    2310         x, y = self.label.get_position()
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2291         for axx in grp.get_siblings(self.axes):
#    2292             ticks_to_draw = axx.yaxis._update_ticks()
# -> 2293             tlb, tlb2 = axx.yaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2294             bboxes.extend(tlb)
#    2295             bboxes2.extend(tlb2)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     336
#     337         # get the rotation matrix
# --> 338         M = Affine2D().rotate_deg(self.get_rotation())
#     339
#     340         # now offset the individual text lines within the box
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/transforms.py in rotate_deg(self, degrees)
#    1936         and :meth:`scale`.
#    1937         """
# -> 1938         return self.rotate(np.deg2rad(degrees))
#    1939
#    1940     def rotate_around(self, x, y, theta):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/transforms.py in rotate(self, theta)
#    1920         and :meth:`scale`.
#    1921         """
# -> 1922         a = np.cos(theta)
#    1923         b = np.sin(theta)
#    1924         rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#
# KeyboardInterrupt:

# %%
df.boxplot(column="likes",by="dislikes")
# Out:
# ------------------------------------------------------------
# KeyboardInterrupt          Traceback (most recent call last)
# <ipython-input-45-cf52690e95bc> in <module>
# ----> 1 df.boxplot(column="likes",by="dislikes")
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     418         layout=layout,
#     419         return_type=return_type,
# --> 420         **kwds
#     421     )
#     422
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     353         layout=layout,
#     354         return_type=return_type,
# --> 355         **kwds
#     356     )
#     357     plt.draw_if_interactive()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     300             ax=ax,
#     301             layout=layout,
# --> 302             return_type=return_type,
#     303         )
#     304     else:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     205         gp_col = grouped[col]
#     206         keys, values = zip(*gp_col)
# --> 207         re_plotf = plotf(keys, values, ax, **kwargs)
#     208         ax.set_title(col)
#     209         ax.set_xlabel(pprint_thing(by))
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in plot_group(keys, values, ax)
#     262         keys = [pprint_thing(x) for x in keys]
#     263         values = [np.asarray(remove_na_arraylike(v)) for v in values]
# --> 264         bp = ax.boxplot(values, **kwds)
#     265         if fontsize is not None:
#     266             ax.tick_params(axis="both", labelsize=fontsize)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3770                            meanline=meanline, showfliers=showfliers,
#    3771                            capprops=capprops, whiskerprops=whiskerprops,
# -> 3772                            manage_ticks=manage_ticks, zorder=zorder)
#    3773         return artists
#    3774
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#    4094
#    4095             # draw the medians
# -> 4096             medians.extend(doplot(med_x, med_y, **final_medianprops))
#    4097
#    4098             # maybe draw the means
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in doplot(*args, **kwargs)
#    3996         if vert:
#    3997             def doplot(*args, **kwargs):
# -> 3998                 return self.plot(*args, **kwargs)
#    3999
#    4000             def dopatch(xs, ys, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1667         for line in lines:
#    1668             self.add_line(line)
# -> 1669         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1670         return lines
#    1671
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2413                 (self._xmargin and scalex and self._autoscaleXon) or
#    2414                 (self._ymargin and scaley and self._autoscaleYon)):
# -> 2415             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2416             x_stickies = np.array([x for sticky in stickies for x in sticky.x])
#    2417             y_stickies = np.array([y for sticky in stickies for y in sticky.y])
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2413                 (self._xmargin and scalex and self._autoscaleXon) or
#    2414                 (self._ymargin and scaley and self._autoscaleYon)):
# -> 2415             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2416             x_stickies = np.array([x for sticky in stickies for x in sticky.x])
#    2417             y_stickies = np.array([y for sticky in stickies for y in sticky.y])
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in sticky_edges(self)
#    1039
#    1040         """
# -> 1041         return self._sticky_edges
#    1042
#    1043     def update_from(self, other):
#
# KeyboardInterrupt:
